# %%
from luwiji.summary import illustration

# %%
illustration.machine_learning

# %%
illustration.tools

# %%
illustration.ml_essentials

# %%
illustration.ml_algorithms

# %%
illustration.metrics_evaluation

# %%
illustration.review1

# %%
illustration.review2
