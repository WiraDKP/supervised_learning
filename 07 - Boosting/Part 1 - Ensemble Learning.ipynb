# %%
from luwiji.ensemble_learning import illustration

# %% [markdown]
# Ide bagging seperti di Random Forest sangat brilian, ternyata ada teknik lain yang serupa. Metode yang memanfaatkan beberapa model disebut sebagai ensemble learning

# %%
illustration.ensemble

# %% [markdown]
# ## Bagging = Strong learner -> Good Learner

# %%
illustration.bagging

# %% [markdown]
# ## Boosting = Weak learner -> Good learner

# %%
illustration.boosting
